# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../../Datasets/census.csv")
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
import timeit

# %%
# %%timeit -n 3

for state in df["STATE"].unique():
    avg = np.average(df.where(df["STATE"] == state).dropna()["CENSUS2010POP"])
    print("The counties in state "+str(state)+ " have the average population of "+str(avg))
# Out:
# The counties in state 1 have the average population of 140580.4705882353
# The counties in state 2 have the average population of 47348.73333333333
# The counties in state 4 have the average population of 799002.125
# The counties in state 5 have the average population of 76734.68421052632
# The counties in state 6 have the average population of 1262845.9661016949
# The counties in state 8 have the average population of 154744.4923076923
# The counties in state 9 have the average population of 794243.7777777778
# The counties in state 10 have the average population of 448967.0
# The counties in state 11 have the average population of 601723.0
# The counties in state 12 have the average population of 552979.7058823529
# The counties in state 13 have the average population of 121095.6625
# The counties in state 15 have the average population of 453433.6666666667
# The counties in state 16 have the average population of 69670.3111111111
# ...

# %%
# %%timeit -n 3

for group,frame in df.groupby("STATE"):
    avg = np.average(frame["CENSUS2010POP"])
    print("the counties in state "+str(group)+" having the population of "+str(avg))
# Out:
# the counties in state 1 having the population of 140580.4705882353
# the counties in state 2 having the population of 47348.73333333333
# the counties in state 4 having the population of 799002.125
# the counties in state 5 having the population of 76734.68421052632
# the counties in state 6 having the population of 1262845.9661016949
# the counties in state 8 having the population of 154744.4923076923
# the counties in state 9 having the population of 794243.7777777778
# the counties in state 10 having the population of 448967.0
# the counties in state 11 having the population of 601723.0
# the counties in state 12 having the population of 552979.7058823529
# the counties in state 13 having the population of 121095.6625
# the counties in state 15 having the population of 453433.6666666667
# the counties in state 16 having the population of 69670.3111111111
# the counties in state 17 having the population of 249138.4854368932
# ...

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df = pd.read_csv("../../Datasets/census.csv")
df.set_index("STATE")

def set_batch_number(item):
    if item < 30:
        return 0
    if item < 57:
        return 1
    return 2

for group,frame in df.groupby(set_batch_number):
    print("The group "+str(group)+" has the count of "+str(len(frame)))
# Out:
# The group 0 has the count of 30
# The group 1 has the count of 27
# The group 2 has the count of 3136

# %%
df = pd.read_csv("../../Datasets/listings.csv")
pattern = "^(review[\w]*)"
df.columns.str.extract(pattern).dropna()
# len(df.columns)
# Out:
#                               0
# 79         review_scores_rating
# 80       review_scores_accuracy
# 81    review_scores_cleanliness
# 82        review_scores_checkin
# 83  review_scores_communication
# 84       review_scores_location
# 85          review_scores_value
# 94            reviews_per_month

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../../Datasets/listings.csv")
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# ...

# %%
df=df.set_index(["cancellation_policy","review_scores_value"])

for group,frame in df.groupby(level=(0,1)):
    print(group)
# Out:
# ('flexible', 2.0)
# ('flexible', 4.0)
# ('flexible', 5.0)
# ('flexible', 6.0)
# ('flexible', 7.0)
# ('flexible', 8.0)
# ('flexible', 9.0)
# ('flexible', 10.0)
# ('moderate', 2.0)
# ('moderate', 4.0)
# ('moderate', 6.0)
# ('moderate', 7.0)
# ('moderate', 8.0)
# ('moderate', 9.0)
# ('moderate', 10.0)
# ('strict', 2.0)
# ('strict', 3.0)
# ('strict', 4.0)
# ('strict', 5.0)
# ('strict', 6.0)
# ('strict', 7.0)
# ('strict', 8.0)
# ('strict', 9.0)
# ('strict', 10.0)
# ('super_strict_30', 6.0)
# ('super_strict_30', 7.0)
# ('super_strict_30', 8.0)
# ('super_strict_30', 9.0)
# ('super_strict_30', 10.0)

# %%
def grouping_fun(item):
    if item[1] == 10.0:
        return (item[0],'10.0')
    else:
        return (item[0],"not 10.0") 
    
for group,frame in df.groupby(grouping_fun):
    print(group)
# Out:
# ('flexible', '10.0')
# ('flexible', 'not 10.0')
# ('moderate', '10.0')
# ('moderate', 'not 10.0')
# ('strict', '10.0')
# ('strict', 'not 10.0')
# ('super_strict_30', '10.0')
# ('super_strict_30', 'not 10.0')

# %%
df.head(5)
# Out:
#                                                id  \
# cancellation_policy review_scores_value
# moderate            NaN                  12147973
#                     9.0                   3075044
#                     10.0                     6976
#                     10.0                  1436513
# flexible            10.0                  7651065
#
#                                                                    listing_url  \
# cancellation_policy review_scores_value
# moderate            NaN                  https://www.airbnb.com/rooms/12147973
#                     9.0                   https://www.airbnb.com/rooms/3075044
#                     10.0                     https://www.airbnb.com/rooms/6976
#                     10.0                  https://www.airbnb.com/rooms/1436513
# flexible            10.0                  https://www.airbnb.com/rooms/7651065
#
#                                               scrape_id last_scraped  \
# ...

# %%
df.reset_index()
# Out:
#      cancellation_policy  review_scores_value        id  \
# 0               moderate                  NaN  12147973
# 1               moderate                  9.0   3075044
# 2               moderate                 10.0      6976
# 3               moderate                 10.0   1436513
# 4               flexible                 10.0   7651065
# ...                  ...                  ...       ...
# 3580              strict                  9.0   8373729
# 3581              strict                  NaN  14844274
# 3582            flexible                  NaN  14585486
# 3583              strict                  7.0  14603878
# 3584            flexible                  NaN  14504422
#
#                                 listing_url       scrape_id last_scraped  \
# 0     https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 1      https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
# ...

# %%
df.groupby("cancellation_policy").agg(["sum","mean"])["calculated_host_listings_count"]
# Out:
# C:\Users\SPURUSHO\AppData\Local\Temp\ipykernel_20340\1405925052.py:1: FutureWarning: ['listing_url', 'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'street', 'neighbourhood', 'neighbourhood_cleansed', 'city', 'state', 'zipcode', 'market', 'smart_location', 'country_code', 'country', 'is_location_exact', 'property_type', 'room_type', 'bed_type', 'amenities', 'price', 'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee', 'extra_people', 'calendar_updated', 'calendar_last_scraped', 'first_review', 'las
# ...
